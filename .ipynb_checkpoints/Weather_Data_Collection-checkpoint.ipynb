# %% [markdown]
# <h1>Step 1: Collecting Data</h1>

# %% [markdown]
# ---

# %%
from requests_html import HTML
import urllib.robotparser
import pandas as pd
import datetime
import time
from selenium.common.exceptions import WebDriverException
from selenium import webdriver

# %% [markdown]
# Check file robot.txt

# %%
rp = urllib.robotparser.RobotFileParser()
rp.set_url('https://www.worldweatheronline.com//robots.txt')
rp.read()
rp.can_fetch('*', 'https://www.worldweatheronline.com/ho-chi-minh-city-weather-history/vn.aspx')
# Out:
# True

# %% [markdown]
# Dùng thư viện Selenium để tương tác với trang web và requests_html để parse html

# %%
browser = webdriver.Chrome(executable_path='chromedriver.exe')
browser.get('https://www.worldweatheronline.com/ho-chi-minh-city-weather-history/vn.aspx')

# %%
f = open('weatherHCM.csv', 'w', encoding='utf-8')
f.write('Date\tTime\tWeather\tTemp\tFeels\tWind\tGust\tRain\tHumidity\tCloud\tPressure\tVis\n')

date = datetime.datetime(2009, 1, 1)
end_date = datetime.datetime(2020, 12, 21)
date_col = ''

record = ['Time', 'Weather', 'Temp', 'Feels', 'Wind', 'Gust', 'Rain', 'Humidity', 'Cloud', 'Pressure', 'Vis']
n_cols = len(record)

while date < end_date:
    date_str = date.strftime('%Y-%m-%d')
    
    # Adjust date
    input_date = browser.find_element_by_id('ctl00_MainContentHolder_txtPastDate')
    browser.execute_script("arguments[0].value = arguments[1];", input_date, date_str)
    submit_date = browser.find_element_by_id('ctl00_MainContentHolder_butShowPastWeather')
    
    try:
        submit_date.click()
    except WebDriverException:
        print(f'Error: Date {date_str}')
        continue
        
    time.sleep(1) # wait for loading the page
    
    # parse html and write to file
    html = HTML(html=browser.page_source)
    yesterday = date_col 
    date_col = html.find('.card-header',first=True).find('h5', first=True).text + ' ' + str(date.year)
    if date_col == yesterday:
        continue
        
    date += datetime.timedelta(days=1)
        
    cols = html.find('.col')[20:108]   # rewrite in good code
    
    i = 0
    for col in cols:
        record[i % n_cols] = col.text
        i += 1

        if i % n_cols == 0:
            f.write(f'{date_col}\t{record[0]}\t{record[1]}\t{record[2]}\t{record[3]}\t{record[4]}\t{record[5]}\t{record[6]}\t{record[7]}\t{record[8]}\t{record[9]}\t{record[10]}\n')
    
f.close()

# %% [markdown]
# Kết quả thu được tập dữ liệu gần 35000 dòng và 12 cột

# %%
data = pd.read_csv('weatherHCM.csv', sep='\t')
data
# Out:
#                    Date   Time        Weather   Temp  Feels              Wind  \
# 0      Tue 06, Jan 2009  00:00          Clear  23 °c  26 °c   6 km/h from NNE
# 1      Tue 06, Jan 2009  03:00          Clear  22 °c  23 °c     8 km/h from N
# 2      Tue 06, Jan 2009  06:00          Sunny  22 °c  26 °c     4 km/h from N
# 3      Tue 06, Jan 2009  09:00          Sunny  27 °c  31 °c   6 km/h from NNE
# 4      Tue 06, Jan 2009  12:00          Sunny  31 °c  38 °c   1 km/h from ENE
# ...                 ...    ...            ...    ...    ...               ...
# 34971  Sun 20, Dec 2020  09:00  Partly cloudy  26 °c  28 °c  17 km/h from NNE
# 34972  Sun 20, Dec 2020  12:00  Partly cloudy  30 °c  31 °c  17 km/h from NNE
# 34973  Sun 20, Dec 2020  15:00  Partly cloudy  31 °c  33 °c  14 km/h from WSW
# 34974  Sun 20, Dec 2020  18:00  Partly cloudy  28 °c  30 °c   15 km/h from SE
# 34975  Sun 20, Dec 2020  21:00  Partly cloudy  25 °c  27 °c  14 km/h from NNE
#
#           Gust    Rain Humidity Cloud Pressure        Vis
# 0      11 km/h  0.0 mm      84%   22%  1011 mb  Excellent
# 1      13 km/h  0.0 mm      86%   24%  1011 mb  Excellent
# 2       4 km/h  0.0 mm      85%   21%  1012 mb  Excellent
# 3       7 km/h  0.0 mm      70%   23%  1013 mb  Excellent
# 4       2 km/h  0.0 mm      58%   10%  1010 mb  Excellent
# ...        ...     ...      ...   ...      ...        ...
# 34971  22 km/h  0.0 mm      64%   14%  1012 mb  Excellent
# 34972  19 km/h  0.0 mm      54%   13%  1010 mb  Excellent
# 34973  18 km/h  0.0 mm      55%   12%  1008 mb  Excellent
# 34974  24 km/h  0.0 mm      60%   18%  1009 mb  Excellent
# 34975  22 km/h  0.0 mm      64%   15%  1011 mb  Excellent
#
# [34976 rows x 12 columns]
